# %%
import sys
from ipywidgets import interact
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from download import download
import numpy as np
# %matplotlib notebook

# %%
pd.set_option('display.max_rows', 50000)

# %%
df_bikes = pd.read_csv("bicycle_db.csv",
                       na_values="", converters={'data': str, 'heure': str})
# Out:
# C:\Users\cindy\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5,6,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_bikes['heure'] = df_bikes['heure'].replace('', np.nan)
df_bikes.iloc[400:402]
# Out:
#      identifiant accident        date          mois          jour heure  \
# 400          200500008935  2005-02-13  02 - février  6 - dimanche   NaN
# 401          200500008941  2005-02-14  02 - février     0 - lundi    15
#
#     departement commune  lat  lon en agglomeration  ... existence securite  \
# 400          75   75018  0.0  0.0              oui  ...             Casque
# 401          75   75007  0.0  0.0              oui  ...             Casque
#
#     usage securite obstacle fixe heurte obstacle mobile heurte  \
# 400            Oui                  NaN               Véhicule
# 401            Oui                  NaN               Véhicule
#
#     localisation choc                manoeuvre avant accident  \
# 400      Avant gauche  Dans le couloir bus, dans le même sens
# 401       Avant droit            Sans changement de direction
#
#      identifiant vehicule type autres vehicules manoeuvre autres vehicules  \
# 400       200500008935B01               VL seul          Tournant a droite
# 401       200500008941A01               VL seul              En s’insérant
#
#      nombre autres vehicules
# 400                      1.0
# 401                      1.0
#
# [2 rows x 39 columns]

# %%
df_bikes.dropna(subset=['heure'], inplace=True)
df_bikes.iloc[399:402]
# Out:
#      identifiant accident        date          mois          jour heure  \
# 399          200500008875  2005-02-10  02 - février     3 - jeudi    15
# 401          200500008941  2005-02-14  02 - février     0 - lundi    15
# 402          200500008961  2005-02-11  02 - février  4 - vendredi    12
#
#     departement commune  lat  lon en agglomeration  ... existence securite  \
# 399          75   75016  0.0  0.0              oui  ...                NaN
# 401          75   75007  0.0  0.0              oui  ...             Casque
# 402          75   75005  0.0  0.0              oui  ...             Casque
#
#     usage securite obstacle fixe heurte obstacle mobile heurte  \
# 399            NaN                  NaN               Véhicule
# 401            Oui                  NaN               Véhicule
# 402            Oui                  NaN               Véhicule
#
#     localisation choc      manoeuvre avant accident  identifiant vehicule  \
# 399           Arrière  Sans changement de direction       200500008875B01
# 401       Avant droit  Sans changement de direction       200500008941A01
# 402      Avant gauche  Sans changement de direction       200500008961A01
#
#     type autres vehicules    manoeuvre autres vehicules  \
# 399            Bicyclette  Sans changement de direction
# 401               VL seul                 En s’insérant
# 402   Scooter immatriculé  Sans changement de direction
#
#      nombre autres vehicules
# 399                      1.0
# 401                      1.0
# 402                      1.0
#
# [3 rows x 39 columns]

# %%
df_bikes['date'] + ' ' + df_bikes['heure'] + ':00'
# Out:
# 0        2005-01-13 19:00
# 1        2005-01-19 10:00
# 2        2005-01-26 13:00
# 3        2005-01-03 13:00
# 4        2005-01-29 18:00
#                ...
# 65976     2018-09-27 8:00
# 65977    2018-03-21 18:00
# 65978    2018-03-31 17:00
# 65979    2018-03-31 17:00
# 65980    2018-07-31 11:00
# Length: 65515, dtype: object

# %%
# on change le format pour la date et l'horaire pour qu'il corresponde au format usuel :

time_improved = pd.to_datetime(df_bikes['date'] +
                               ' ' + df_bikes['heure'] + ':00',
                               format='%Y-%m-%d %H:%M')

# avec d = day, m=month, Y=year, H=hour, M=minutes

# %%
df_bikes['Time'] = time_improved
df_bikes.set_index('Time', inplace=True)
# on enlève les colonnes inutiles
del df_bikes['heure']
del df_bikes['date']

# %%
df_bikes
# Out:
#                      identifiant accident            mois          jour  \
# Time
# 2005-01-13 19:00:00          200500000030    01 - janvier     3 - jeudi
# 2005-01-19 10:00:00          200500000034    01 - janvier  2 - mercredi
# 2005-01-26 13:00:00          200500000078    01 - janvier  2 - mercredi
# 2005-01-03 13:00:00          200500000093    01 - janvier     0 - lundi
# 2005-01-29 18:00:00          200500000170    01 - janvier    5 - samedi
# ...                                   ...             ...           ...
# 2018-09-27 08:00:00          201800057521  09 - septembre     3 - jeudi
# 2018-03-21 18:00:00          201800057582       03 - mars  2 - mercredi
# 2018-03-31 17:00:00          201800057587       03 - mars    5 - samedi
# 2018-03-31 17:00:00          201800057587       03 - mars    5 - samedi
# 2018-07-31 11:00:00          201800057676    07 - juillet     1 - mardi
#
#                     departement commune       lat       lon en agglomeration  \
# Time
# 2005-01-13 19:00:00          62   62331  50.30000   2.84000              oui
# 2005-01-19 10:00:00          62   62022   0.00000   0.00000              non
# 2005-01-26 13:00:00           2    2173   0.00000   0.00000              non
# 2005-01-03 13:00:00           2    2810  49.25500   3.09400              oui
# 2005-01-29 18:00:00          76   76196   0.00000   0.00000              non
# ...                         ...     ...       ...       ...              ...
# 2018-09-27 08:00:00         974   97416 -21.29643  55.46052              non
# 2018-03-21 18:00:00         976   97611 -12.76833  45.22532              oui
# 2018-03-31 17:00:00         976   97611 -12.78604  45.22107              oui
# 2018-03-31 17:00:00         976   97611 -12.78604  45.22107              oui
# 2018-07-31 11:00:00         976   97611 -12.77302  45.22106              oui
#
#                       type intersection                  type collision  ...  \
# Time                                                                     ...
# 2005-01-13 19:00:00   Hors intersection    Deux véhicules - par le coté  ...
# 2005-01-19 10:00:00   Hors intersection       Deux véhicules - frontale  ...
# 2005-01-26 13:00:00  Autre intersection    Deux véhicules - par le coté  ...
# 2005-01-03 13:00:00   Hors intersection       Deux véhicules - frontale  ...
# 2005-01-29 18:00:00   Hors intersection  Deux véhicules - par l’arrière  ...
# ...                                 ...                             ...  ...
# 2018-09-27 08:00:00   Hors intersection    Deux véhicules - par le coté  ...
# 2018-03-21 18:00:00  Autre intersection  Deux véhicules - par l’arrière  ...
# 2018-03-31 17:00:00   Hors intersection    Deux véhicules - par le coté  ...
# 2018-03-31 17:00:00   Hors intersection    Deux véhicules - par le coté  ...
# 2018-07-31 11:00:00   Hors intersection                           Autre  ...
#
#                      existence securite    usage securite  \
# Time
# 2005-01-13 19:00:00                 NaN               NaN
# 2005-01-19 10:00:00                 NaN               NaN
# 2005-01-26 13:00:00              Casque               Non
# 2005-01-03 13:00:00                 NaN               NaN
# 2005-01-29 18:00:00               Autre               Oui
# ...                                 ...               ...
# 2018-09-27 08:00:00              Casque               Oui
# 2018-03-21 18:00:00              Casque               Oui
# 2018-03-31 17:00:00               Autre  Non déterminable
# 2018-03-31 17:00:00               Autre  Non déterminable
# 2018-07-31 11:00:00  Dispositif enfants               NaN
#
#                     obstacle fixe heurte obstacle mobile heurte  \
# Time
# 2005-01-13 19:00:00                  NaN               Véhicule
# 2005-01-19 10:00:00                  NaN               Véhicule
# 2005-01-26 13:00:00                  NaN               Véhicule
# 2005-01-03 13:00:00                  NaN               Véhicule
# 2005-01-29 18:00:00                  NaN               Véhicule
# ...                                  ...                    ...
# 2018-09-27 08:00:00                  NaN               Véhicule
# 2018-03-21 18:00:00                  NaN               Véhicule
# 2018-03-31 17:00:00                  NaN               Véhicule
# 2018-03-31 17:00:00                  NaN               Véhicule
# 2018-07-31 11:00:00                  NaN                 Piéton
#
#                      localisation choc      manoeuvre avant accident  \
# Time
# 2005-01-13 19:00:00        Côté gauche    Changeant de file à gauche
# 2005-01-19 10:00:00              Avant  Sans changement de direction
# 2005-01-26 13:00:00              Avant  Sans changement de direction
# 2005-01-03 13:00:00       Avant gauche          Manœuvre d’évitement
# 2005-01-29 18:00:00            Arrière          Même sens, même file
# ...                                ...                           ...
# 2018-09-27 08:00:00              Avant          Même sens, même file
# 2018-03-21 18:00:00       Avant gauche                 En s’insérant
# 2018-03-31 17:00:00        Côté gauche                           NaN
# 2018-03-31 17:00:00        Côté gauche                           NaN
# 2018-07-31 11:00:00              Avant                           NaN
#
#                     identifiant vehicule  \
# Time
# 2005-01-13 19:00:00      200500000030B02
# 2005-01-19 10:00:00      200500000034B02
# 2005-01-26 13:00:00      200500000078B02
# 2005-01-03 13:00:00      200500000093B02
# 2005-01-29 18:00:00      200500000170A01
# ...                                  ...
# 2018-09-27 08:00:00      201800057521B01
# 2018-03-21 18:00:00      201800057582B01
# 2018-03-31 17:00:00      201800057587B01
# 2018-03-31 17:00:00      201800057587B01
# 2018-07-31 11:00:00      201800057676A01
#
#                                                  type autres vehicules  \
# Time
# 2005-01-13 19:00:00                                Transport en commun
# 2005-01-19 10:00:00  VU seul 1,5T <= PTAC <= 3,5T avec ou sans remo...
# 2005-01-26 13:00:00                                            VL seul
# 2005-01-03 13:00:00                                            VL seul
# 2005-01-29 18:00:00  VU seul 1,5T <= PTAC <= 3,5T avec ou sans remo...
# ...                                                                ...
# 2018-09-27 08:00:00                                            VL seul
# 2018-03-21 18:00:00                                            VL seul
# 2018-03-31 17:00:00                                            VL seul
# 2018-03-31 17:00:00                                            VL seul
# 2018-07-31 11:00:00                                                NaN
#
#                      manoeuvre autres vehicules nombre autres vehicules
# Time
# 2005-01-13 19:00:00          Dépassant à gauche                     1.0
# 2005-01-19 10:00:00           Tournant à gauche                     1.0
# 2005-01-26 13:00:00           Tournant à gauche                     1.0
# 2005-01-03 13:00:00        Manœuvre d’évitement                     1.0
# 2005-01-29 18:00:00        Même sens, même file                     1.0
# ...                                         ...                     ...
# 2018-09-27 08:00:00           Tournant à gauche                     1.0
# 2018-03-21 18:00:00        Même sens, même file                     1.0
# 2018-03-31 17:00:00          Dépassant à gauche                     1.0
# 2018-03-31 17:00:00          Dépassant à gauche                     1.0
# 2018-07-31 11:00:00                         NaN                     NaN
#
# [65515 rows x 37 columns]

# %%
# Chargement des couleurs
sns.set_palette("colorblind", n_colors=7)
df_bikes['weekday'] = df_bikes.index.weekday  # Monday=0, Sunday=6

days = ['Lundi', 'Mardi', 'Mercredi',
        'Jeudi', 'Vendredi', 'Samedi', 'Dimanche']

accidents_week = df_bikes.groupby(['weekday', df_bikes.index.hour])[
    'sexe'].count().unstack(level=0)


fig, axes = plt.subplots(1, 1, figsize=(7, 7))


accidents_week.plot(ax=axes)
axes.set_ylabel("Accidents")
axes.set_xlabel("Heure de la journée")
axes.set_title(
    "Profil journalier des accidents: effet du weekend?")
axes.set_xticks(np.arange(0, 24))
axes.set_xticklabels(np.arange(0, 24), rotation=45)
axes.legend(labels=days, loc='lower left', bbox_to_anchor=(1, 0.1))

plt.tight_layout()

# %%
accidents_week = df_bikes.sort_values(['Time'])
# L'input est composé de toutes les données :
input = accidents_week
# L'output est composé des données de 2018 uniquement :
output = accidents_week.iloc[63389:, :]

# %%
accidents_week = input.groupby(['weekday', input.index.hour])[
    'sexe'].count().unstack(level=0)
accidents_d = accidents_week.sum()
# Nombre d'accidents par jour de la semaine en moyenne par année :
print(accidents_d/14)
accidents_d = accidents_d/14
accidents_week_2018 = output.groupby(['weekday', output.index.hour])[
    'sexe'].count().unstack(level=0)
accidents_d_2018 = accidents_week_2018.sum()
# Nombre d'accidents par jour de la semaine en 2018 :
print(accidents_d_2018)
accident_2018 = accidents_d_2018
# Out:
# weekday
# 0    648.500000
# 1    746.071429
# 2    788.642857
# 3    748.500000
# 4    729.642857
# 5    553.142857
# 6    465.142857
# dtype: float64
# weekday
# 0    250.0
# 1    331.0
# 2    336.0
# 3    332.0
# 4    335.0
# 5    288.0
# 6    254.0
# dtype: float64

# %%
fig = plt.figure()
plt.plot(accidents_d)
plt.plot(accident_2018)
plt.show()

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
width = 6
raw_x = np.array(accidents_d)
raw_y = np.array(accident_2018)
# Plot de l'input et de l'output
fig = plt.figure(figsize=(7, 7))
ax = plt.axes()
ax.plot(raw_x, "r.-", label="input")
ax.plot(raw_y, "b.-", label="output")
ax.set_xlabel("Jour de la semaine")
ax.set_ylabel("Accidents")
ax.legend()
plt.title("Moyenne du nombe d'accidents par jour de la semaine (Lundi = 0, ..., Dimanche=6)")
plt.grid()

# %%
T = len(raw_x)
A = np.zeros((T, width))
A[0:, 0] = raw_x[0:]
for i in range(1, width):
    # On crée la matrice qui va permettre de résoudre l'équation Y=AW, avec W la matrice de coefficients du modèle
    A[i:, i] = raw_x[0:-i]
A
# Out:
# array([[648.5       ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [746.07142857, 648.5       ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [788.64285714, 746.07142857, 648.5       ,   0.        ,
#           0.        ,   0.        ],
#        [748.5       , 788.64285714, 746.07142857, 648.5       ,
#           0.        ,   0.        ],
#        [729.64285714, 748.5       , 788.64285714, 746.07142857,
#         648.5       ,   0.        ],
#        [553.14285714, 729.64285714, 748.5       , 788.64285714,
#         746.07142857, 648.5       ],
#        [465.14285714, 553.14285714, 729.64285714, 748.5       ,
#         788.64285714, 746.07142857]])

# %%
# Résultat de A^-1Y=W
wop = np.dot(np.linalg.pinv(A), raw_y)

# %%
np.shape(wop)
# Out:
# (6,)

# %%
# Grâce aux coefficients estimés, on peut estimer Y :
y_pred = np.dot(A, wop)
y_pred
# Out:
# array([250.67477544, 330.16314958, 336.22796257, 331.59008569,
#        334.63676793, 291.88914827, 250.61947562])

# %%
# Comparaison de la prédiction et de la vraie valeur de Y : avec width = 6, on obtient deux courbes quasi superposées. On remarque que comme pour 2017, le mercredi est un jour avec beaucoup d'accidents contrairement au week-end
fig = plt.figure(figsize=(7, 7))
ax = plt.axes()
ax.plot(accident_2018, "r.-", label="real_output")
ax.plot(y_pred, "b.-", label="prediction")
ax.set_xlabel("Jour de la semaine")
ax.set_ylabel("Accidents")
ax.legend()
plt.grid()
plt.title("Moyenne du nombe d'accidents par jour de la semaine en 2018 (Lundi = 0, ..., Dimanche=6)")
# Out:
# Text(0.5, 1.0, "Moyenne du nombe d'accidents par jour de la semaine en 2018 (Lundi = 0, ..., Dimanche=6)")

# %%
# Quelle valeur aurait-il fallu choisir pour width ? Pour le savoir, on va calculer l'erreur de prédiction pour plusieurs valeurs de width.
err = []
max_window = 200
raw_x = np.array(np.array(accidents_d))
raw_y = np.array(np.array(accident_2018))
T = len(raw_x)
for width in range(1, max_window+1):
    A = np.zeros((T, width))
    A[0:, 0] = raw_x[0:]
    for i in range(1, width):
        A[i:, i] = raw_x[0:-i]
    wop = np.dot(np.linalg.pinv(A), raw_y)
    y_pred = np.dot(A, wop)
    err.append(np.linalg.norm(y_pred-raw_y))
err
# Out:
# [75.62777808243885,
#  47.31454121883999,
#  44.182991587912944,
#  31.538066988342273,
#  18.539858318260826,
#  5.29726288042659,
#  5.907341372570309e-13,
#  2.8421709430404007e-13,
#  2.8421709430404007e-13,
#  2.8421709430404007e-13,
#  2.8421709430404007e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13,
#  5.968558980384842e-13]

# %%
# Plot de l'erreur : dès width >= 7, l'erreur tend vers 0, la prédiction sera donc très proche de la vraie valeur pour width>= 7.
fig = plt.figure(figsize=(16, 9))
ax = plt.axes()
ax.plot(err, ".-", label="error")
ax.set_xlabel("width")
ax.set_ylabel("Error")
ax.legend()
plt.grid()
plt.title("Erreur de prédiction en fonction de width")
# Out:
# Text(0.5, 1.0, 'Erreur de prédiction en fonction de width')
